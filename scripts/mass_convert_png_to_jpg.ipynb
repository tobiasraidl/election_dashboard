# %%
import os
from PIL import Image

# Specify the directory containing the images
directory = "../images"

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        # Construct full file path
        file_path = os.path.join(directory, filename)
        
        # Open the PNG image
        with Image.open(file_path) as img:
            # Convert to RGB (required for saving as JPG)
            rgb_image = img.convert("RGB")
            
            # Save the image as JPG
            new_filename = os.path.splitext(filename)[0] + ".jpg"
            rgb_image.save(os.path.join(directory, new_filename), "JPEG")
        
        # Remove the original PNG file
        os.remove(file_path)
        print(f"Converted and removed {filename}")
# Out:
# Converted and removed 0143f6f4fab16c0b.png
# Converted and removed 0173fe8d8626ca7a.png
# Converted and removed 017de9dbd7390905.png
# Converted and removed 0193fc2ff44c74b8.png
# Converted and removed 019afe65e64556b8.png
# Converted and removed 01f197f723a7a216.png
# Converted and removed 0311bda16a6fe0e7.png
# Converted and removed 03129e65e4fc98de.png
# Converted and removed 0342fcfca9a35656.png
# Converted and removed 034c7c83ec237c7d.png
# Converted and removed 0353f8fcfc2c9c03.png
# Converted and removed 03838e7e0ed6b1f8.png
# Converted and removed 03913cfd4aecec32.png
# Converted and removed 03ecf813edec0359.png
# Converted and removed 052bf4526ad585be.png
# Converted and removed 05355edab561caf0.png
# Converted and removed 0580b5fcfc5e4b16.png
# Converted and removed 05a467e9e9b04577.png
# Converted and removed 05b063dc9ee1639e.png
# Converted and removed 05b47be48e38eae1.png
# Converted and removed 05f91b36e69819e6.png
# Converted and removed 07718cdd892de378.png
# Converted and removed 0786bc38cf0a7bb8.png
# Converted and removed 07b37afac505f818.png
# Converted and removed 091946bbd4e67a1d.png
# Converted and removed 09df6233fc3f4025.png
# Converted and removed 0b02a5f5d3dae466.png
# Converted and removed 0d6992f1ce36616e.png
# Converted and removed 0f1ed68da9631876.png
# Converted and removed 0ffbc09c7285b8c6.png
# Converted and removed 1153ac2de61ac7ec.png
# Converted and removed 115da72a1c13b5e7.png
# Converted and removed 118b96254f3f67e0.png
# Converted and removed 130bfeba29494c76.png
# Converted and removed 13180da6ddec66d9.png
# Converted and removed 136d5ca6915372cd.png
# Converted and removed 15d16bb4fe4303b4.png
# Converted and removed 1798251fce60cb67.png
# Converted and removed 1b237ee6c3e42711.png
# Converted and removed 1be697610816ecde.png
# Converted and removed 1d0c26a53a3a5ee7.png
# Converted and removed 1d9760ea9d0a6e5a.png
# Converted and removed 1da5b17e6cca0d23.png
# Converted and removed 1f4ac9591cebb894.png
# Converted and removed 1fb54e22566d33c2.png
# Converted and removed 1fe0be40c3bf6489.png
# Converted and removed 214a9ccab4ee756a.png
# Converted and removed 217fb095834b279d.png
# Converted and removed 219d311ee6c63b71.png
# Converted and removed 21c5fa6e1105cbfa.png
# Converted and removed 21d1d163b5ab63a6.png
# Converted and removed 21f9dc0bf6a909d4.png
# Converted and removed 230a7efa1c5594ce.png
# Converted and removed 2312d48e6fe4f0bc.png
# Converted and removed 959a4ce3b41b1e1d.png
# Converted and removed 95bf1f48e4071b64.png
# Converted and removed 973d69c9d9a80acc.png
# Converted and removed 97612ad6dc23396c.png
# Converted and removed 976d49d3639c2c16.png
# Converted and removed 9771acd15ca134cd.png
# Converted and removed 97c9639c4df1340b.png
# Converted and removed 97dae925569a2525.png
# Converted and removed 9932a17d962d7a83.png
# Converted and removed 9b05dbbd714aa60a.png
# Converted and removed 9d606625b1b96575.png
# Converted and removed 9dd8c82c25b6f326.png
# Converted and removed a11e5ef14ca1e19e.png
# Converted and removed a1565e7c7aa134a5.png
# Converted and removed a1619e9e76d38925.png
# Converted and removed a1ca5e59be250bac.png
# Converted and removed a5f8f209860b6eb9.png
# Converted and removed a739598c9566079b.png
# Converted and removed a759868679869a6b.png
# Converted and removed a7664932e6875c3c.png
# Converted and removed a95394ad16ed1396.png
# Converted and removed a96b15bf650ba321.png
# Converted and removed ab2e7416a5f05687.png
# Converted and removed ab5336437492e8ae.png
# Converted and removed ab7776e326038385.png
# Converted and removed af4441fd960871bb.png
# Converted and removed b34963b35524b5b2.png
# Converted and removed b3d793d0aa238b13.png
# Converted and removed b751ab853994ab51.png
# Converted and removed b764691b5999981d.png
# Converted and removed b765238b5a7c9909.png
# Converted and removed b768960909b5ecf4.png
# Converted and removed b7cd47d22b1b0943.png
# Converted and removed b95fbb1c4991292c.png
# Converted and removed bb5609ad47c3858b.png
# Converted and removed bbb055565b85ad11.png
# Converted and removed bd0cf1139b4fe026.png
# Converted and removed bdbc0bacc859b8a4.png
# Converted and removed bf0e051225f1b379.png
# Converted and removed bf252a1a35699e89.png
# Converted and removed bf4359b6a34d4a81.png
# Converted and removed bf7169970b278151.png
# Converted and removed bfba838c25cc634c.png
# Converted and removed bfcd9de10b0b0323.png
# Converted and removed bffe63616182830d.png
# Converted and removed c1737a8d1529d28f.png
# Converted and removed c37abc160da1d6c9.png
# Converted and removed c3c256f79646130f.png
# Converted and removed c78aca5ae0e496b6.png
# Converted and removed c79e9da66679400b.png
# Converted and removed c98d437e72729613.png
# Converted and removed c9b338c3c55e1c4e.png
# Converted and removed c9b523db2c2758c3.png
# Converted and removed cbbc239e2165f609.png
# Converted and removed cd1236e623fc134d.png
# Converted and removed cd96dad2412db6c8.png
# Converted and removed cf415f85f71c2309.png
# Converted and removed d195b9790da26972.png
# Converted and removed d3131fd2ad7c202d.png
# Converted and removed d5f08b8d940e6d74.png
# Converted and removed d706d1e3e903b43c.png
# Converted and removed d79303dc92d6c994.png
# Converted and removed d90ab73506f42766.png
# Converted and removed d918276c27bc4af1.png
# Converted and removed d988b9f9833e29c2.png
# Converted and removed dd3322dd2651ad4a.png
# Converted and removed dd5c1b3338bc2c23.png
# Converted and removed df01d836619e6758.png
# Converted and removed df4a1209a5b92d73.png
# Converted and removed dfac93a055269c93.png
# Converted and removed dfca792909b581c6.png
# Converted and removed e11d52e95ee1e146.png
# Converted and removed e1f7ac0a1c59bca8.png
# Converted and removed e39d3a2c9562f458.png
# Converted and removed e702f97bcee44142.png
# Converted and removed e7661999194eb133.png
# Converted and removed e7ee1d90c29c9196.png
# Converted and removed e91f57d09b07e015.png
# Converted and removed e95e1c93e4633493.png
# Converted and removed e98e345256cb2d72.png
# Converted and removed e99658651e99646e.png
# Converted and removed e9de876019c6b12e.png
# Converted and removed eb871e5bc7890c13.png
# Converted and removed edf81327ec833126.png
# Converted and removed ef25da9901ab948b.png
# Converted and removed ef31d4d42bd20b0b.png
# Converted and removed ef6a69680757096c.png
# Converted and removed efa70862d0a76bc2.png
# Converted and removed efcec3343e0b2491.png
# Converted and removed f13887c836661cde.png
# Converted and removed f18d32738f952b05.png
# Converted and removed f1e0a90812f7fde0.png
# Converted and removed f3a4059b1f965171.png
# Converted and removed f500a4382bde4be7.png
# Converted and removed f55f09c2d235216d.png
# Converted and removed f5b5930b7c0b03e4.png
# Converted and removed f5c319a5a9462b71.png
# Converted and removed f5d1474b2923ad0b.png
# Converted and removed f5d3470b2921ad4b.png
# Converted and removed f5d3470b2923a94b.png
# Converted and removed f5f389570b0e0527.png
# Converted and removed f761034d1a07dce9.png
# Converted and removed f7ec29d653892303.png
# Converted and removed f9df216639221e29.png
# Converted and removed fb07192cdcd61a1a.png
# Converted and removed fd0743cb1b61833a.png
# Converted and removed fd1303ec7613ac29.png
# Converted and removed fd2626288c94d67e.png
# Converted and removed fd3303ccac32d649.png
# Converted and removed fd3303ccec32d609.png
# Converted and removed fd59830770f8d816.png
# Converted and removed fd66939589c35261.png
# Converted and removed fd6c694595b48383.png
# Converted and removed fd7a0b99a1c19c25.png
# Converted and removed fd890376ac8d5269.png
# Converted and removed fdb503025b998537.png
# Converted and removed fdf5a94b07230313.png
# Converted and removed fdfc83034725035b.png
# Converted and removed ff020df8927d23c2.png
# Converted and removed ff0525dee3ac011a.png
# Converted and removed ff0541a1baf8a561.png
# Converted and removed ff0631e00974b9cd.png
# Converted and removed ff0b590387f0e485.png
# Converted and removed ff0b650799b8c813.png
# Converted and removed ff21a1569b896543.png
# Converted and removed ff4927993c0343e8.png
# Converted and removed ff4b1505837a11cd.png
# Converted and removed ff4d8aac55463246.png
# Converted and removed ff4e21a983859d52.png
# Converted and removed ff5505a3c289b19a.png
# Converted and removed ff56674d0464b524.png
# Converted and removed ff9626985c702999.png
# Converted and removed ff9af18d2109170d.png
# Converted and removed ffa509fc03a16683.png
# Converted and removed ffa5430bb4d2218b.png
# Converted and removed ffb3550c296c0569.png
# Converted and removed ffb4116d03134397.png
# Converted and removed ffb55303014b897c.png
# Converted and removed ffb643e409b94303.png
# Converted and removed ffc2490b217d7303.png
# Converted and removed ffc6124c03339cf4.png
# Converted and removed ffc903a5138b6c92.png
# Converted and removed ffd61916890d0771.png
