# %%
import pandas as pd

pd.read_csv('../data/all_posts.csv')
# Out:
#        Unnamed: 0  index               user_id  \
# 0               0      0  ___naturliebhaber___
# 1               1      1  ___naturliebhaber___
# 2               2      2  ___naturliebhaber___
# 3               3      3  ___naturliebhaber___
# 4               4      4  ___naturliebhaber___
# ...           ...    ...                   ...
# 84108       84108  84301       zusammenzukunft
# 84109       84109  84302       zusammenzukunft
# 84110       84110  84303       zusammenzukunft
# 84111       84111  84304       zusammenzukunft
# 84112       84112  84305       zusammenzukunft
#
#                               id_user_post                     name  \
# 0      ig____naturliebhaber____CUPLsaTKhLF  Wir lieben die Natur 😇💚
# 1      ig____naturliebhaber____CUPLsaTKhLF  Wir lieben die Natur 😇💚
# 2      ig____naturliebhaber____CUPLsaTKhLF  Wir lieben die Natur 😇💚
# 3      ig____naturliebhaber____CUPLsaTKhLF  Wir lieben die Natur 😇💚
# ...
