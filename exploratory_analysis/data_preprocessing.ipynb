# %% [markdown]
# Filter out generally irelevant posts for this applications

# %%
import pandas as pd

def create_base_dataframe(file_path):
    df = pd.read_csv(file_path)
    df = df.dropna(subset=["hash"]).reset_index()
    
    # Drop rows where the image only appears once in the entire dataset
    hash_counts = df['hash'].value_counts()
    df = df[df['hash'].isin(hash_counts[hash_counts > 1].index)]
    
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")

    party_mapping = {
        'DIE LINKE': 'die_linke',
        'FDP': 'fdp',
        'DIE GRÜNEN': 'die_gruenen',
        'SPD': 'spd',
        'AFD': 'afd',
        'CDU/CSU': 'cdu_csu'
    }
    df['party'] = df['party'].map(party_mapping)
    df['party'] = df['party'].fillna('unknown')
    
    platform_mapping = {
        'fb': 'Facebook',
        'ig': 'Instagram',
        'tw': 'Twitter'
    }

    df['platform'] = df['platform'].map(platform_mapping)
    return df

df = create_base_dataframe('../data/original_posts.csv')
df.to_csv('../data/base_posts.csv')
print(df.shape[0])
df.head()
# Out:
# 21546
#      index          user_id                    id_user_post            name  \
# 27      27  _andreaschwarz_  ig__andreaschwarz__CUE9BI8K46c  Andrea Schwarz
# 79      79      _germanzero      ig__germanzero_CT35PD_qrBs      GermanZero
# 90      90      _germanzero      ig__germanzero_CTFXm93KHDx      GermanZero
# 96      96      _germanzero      ig__germanzero_CTObUrhq6yX      GermanZero
# 104    104      _germanzero      ig__germanzero_CTh4QP8q8G6      GermanZero
#
#               timestamp   platform                          img_id  \
# 27  2021-09-21 10:43:30  Instagram  ig__andreaschwarz__CUE9BI8K46c
# 79  2021-09-16 09:00:23  Instagram      ig__germanzero_CT35PD_qrBs
# 90  2021-08-27 18:04:27  Instagram    ig__germanzero_CTFXm93KHDx_1
# 96  2021-08-31 06:30:05  Instagram    ig__germanzero_CTObUrhq6yX_1
# 104 2021-09-07 19:48:27  Instagram    ig__germanzero_CTh4QP8q8G6_3
#
#                  hash    party
# 27   33430bfc74ab9c8c  unknown
# 79   074e38788687fc7c  unknown
# 90   edb10b0f9570f449  unknown
# 96   230ddcf31c1a73b4  unknown
# 104  937c6c83e4131ee6  unknown

# %% [markdown]
# Filters out posts where no party to the account is provided.

# %%
def df_with_parties(file_path):
    df = pd.read_csv(file_path)
    df = df[df['party'] != 'unknown']
    df = df.reset_index()
    return df

df = df_with_parties('../data/base_posts.csv')
df.to_csv('../data/posts_with_party.csv')
print(df.shape[0])
df.head()
# Out:
# 5756
#    level_0  Unnamed: 0  index          user_id  \
# 0       14         243    243     100021691363
# 1      136         507    507  100058135027750
# 2      137         508    508  100058135027750
# 3      164         569    569  100063616410667
# 4      165         570    570  100063616410667
#
#                          id_user_post                name  \
# 0   fb_100021691363_10157840358841364          Sören Link
# 1  fb_100058135027750_260335295914303  Wiebke Knell - FDP
# 2  fb_100058135027750_263081198973046  Wiebke Knell - FDP
# 3  fb_100063616410667_229064975890715  Das Grüne Netzwerk
# 4  fb_100063616410667_236140568516489  Das Grüne Netzwerk
#
#              timestamp  platform                              img_id  \
# 0  2021-08-16 16:05:50  Facebook   fb_100021691363_10157840358841364
# 1  2021-08-20 06:33:11  Facebook  fb_100058135027750_260335295914303
# 2  2021-08-24 19:04:43  Facebook  fb_100058135027750_263081198973046
# 3  2021-08-20 07:43:47  Facebook  fb_100063616410667_229064975890715
# 4  2021-08-30 09:03:33  Facebook  fb_100063616410667_236140568516489
#
#                hash        party
# 0  87d5b928361ca35b    die_linke
# 1  d79303dc92d6c994          fdp
# 2  0f931b955567d4c4          fdp
# 3  bfba838c25cc634c  die_gruenen
# 4  3ded252303e6e3a4  die_gruenen

# %% [markdown]
# Drop rows with hashes that appear only for one platform in the entire dataset

# %%
def df_for_cross_platform_images(file_path):
    df = pd.read_csv(file_path)
    hash_platform_counts = df.groupby('hash')['platform'].nunique()
    valid_hashes = hash_platform_counts[hash_platform_counts > 1].index
    df = df[df['hash'].isin(valid_hashes)]
    return df
    
df = df_for_cross_platform_images('../data/base_posts.csv')
df.to_csv('../data/cross_platform_posts.csv')
print(df.shape[0])
df.head()
# Out:
# 9310
#    Unnamed: 0  index          user_id                    id_user_post  \
# 0          27     27  _andreaschwarz_  ig__andreaschwarz__CUE9BI8K46c
# 1          79     79      _germanzero      ig__germanzero_CT35PD_qrBs
# 2          90     90      _germanzero      ig__germanzero_CTFXm93KHDx
# 3          96     96      _germanzero      ig__germanzero_CTObUrhq6yX
# 4         104    104      _germanzero      ig__germanzero_CTh4QP8q8G6
#
#              name            timestamp   platform  \
# 0  Andrea Schwarz  2021-09-21 10:43:30  Instagram
# 1      GermanZero  2021-09-16 09:00:23  Instagram
# 2      GermanZero  2021-08-27 18:04:27  Instagram
# 3      GermanZero  2021-08-31 06:30:05  Instagram
# 4      GermanZero  2021-09-07 19:48:27  Instagram
#
#                            img_id              hash    party
# 0  ig__andreaschwarz__CUE9BI8K46c  33430bfc74ab9c8c  unknown
# 1      ig__germanzero_CT35PD_qrBs  074e38788687fc7c  unknown
# 2    ig__germanzero_CTFXm93KHDx_1  edb10b0f9570f449  unknown
# 3    ig__germanzero_CTObUrhq6yX_1  230ddcf31c1a73b4  unknown
# 4    ig__germanzero_CTh4QP8q8G6_3  937c6c83e4131ee6  unknown
