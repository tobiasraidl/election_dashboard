# %%
import pandas as pd

def create_base_dataframe(file_path):
    df = pd.read_csv(file_path)
    df = df.dropna(subset=["hash"]).reset_index()
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")

    party_mapping = {
        'DIE LINKE': 'die_linke',
        'FDP': 'fdp',
        'DIE GRÜNEN': 'die_gruenen',
        'SPD': 'spd',
        'AFD': 'afd',
        'CDU/CSU': 'cdu_csu'
    }
    df['party'] = df['party'].map(party_mapping)
    df['party'] = df['party'].fillna('unknown')
    
    platform_mapping = {
        'fb': 'Facebook',
        'ig': 'Instagram',
        'tw': 'Twitter'
    }

    df['platform'] = df['platform'].map(platform_mapping)
    return df

df = create_base_dataframe('../data/original_posts.csv')
df.to_csv('../data/all_posts.csv')
print(df.shape[0])
df.head()
# Out:
# 84113
#    index               user_id                         id_user_post  \
# 0      0  ___naturliebhaber___  ig____naturliebhaber____CUPLsaTKhLF
# 1      1  ___naturliebhaber___  ig____naturliebhaber____CUPLsaTKhLF
# 2      2  ___naturliebhaber___  ig____naturliebhaber____CUPLsaTKhLF
# 3      3  ___naturliebhaber___  ig____naturliebhaber____CUPLsaTKhLF
# 4      4  ___naturliebhaber___  ig____naturliebhaber____CURmRoYKCUu
#
#                       name           timestamp   platform  \
# 0  Wir lieben die Natur 😇💚 2021-09-25 10:04:09  Instagram
# 1  Wir lieben die Natur 😇💚 2021-09-25 10:04:09  Instagram
# 2  Wir lieben die Natur 😇💚 2021-09-25 10:04:09  Instagram
# 3  Wir lieben die Natur 😇💚 2021-09-25 10:04:09  Instagram
# 4  Wir lieben die Natur 😇💚 2021-09-26 08:34:54  Instagram
#
#                                   img_id              hash    party
# 0  ig____naturliebhaber____CUPLsaTKhLF_2  597da703705e03f8  unknown
# 1  ig____naturliebhaber____CUPLsaTKhLF_3  8d0d778fa0ed49d0  unknown
# 2  ig____naturliebhaber____CUPLsaTKhLF_4  6dd192bde5ca4425  unknown
# 3  ig____naturliebhaber____CUPLsaTKhLF_5  09f38247bcf8b54a  unknown
# 4    ig____naturliebhaber____CURmRoYKCUu  9bc6c751e7372411  unknown

# %%
def df_with_parties(file_path):
    df = pd.read_csv(file_path)
    df = df[df['party'] != 'unknown']
    df = df.reset_index()
    return df

df = df_with_parties('../data/all_posts.csv')
df.to_csv('../data/posts_with_party.csv')
print(df.shape[0])
df.head()
# Out:
# 14888
#    level_0  Unnamed: 0  index          user_id  \
# 0      243         243    243     100021691363
# 1      507         507    507  100058135027750
# 2      508         508    508  100058135027750
# 3      509         509    509  100058135027750
# 4      569         569    569  100063616410667
#
#                          id_user_post                name  \
# 0   fb_100021691363_10157840358841364          Sören Link
# 1  fb_100058135027750_260335295914303  Wiebke Knell - FDP
# 2  fb_100058135027750_263081198973046  Wiebke Knell - FDP
# 3  fb_100058135027750_271727801441719  Wiebke Knell - FDP
# 4  fb_100063616410667_229064975890715  Das Grüne Netzwerk
#
#              timestamp  platform                              img_id  \
# 0  2021-08-16 16:05:50  Facebook   fb_100021691363_10157840358841364
# 1  2021-08-20 06:33:11  Facebook  fb_100058135027750_260335295914303
# 2  2021-08-24 19:04:43  Facebook  fb_100058135027750_263081198973046
# 3  2021-09-07 10:20:36  Facebook  fb_100058135027750_271727801441719
# 4  2021-08-20 07:43:47  Facebook  fb_100063616410667_229064975890715
#
#                hash        party
# 0  87d5b928361ca35b    die_linke
# 1  d79303dc92d6c994          fdp
# 2  0f931b955567d4c4          fdp
# 3  5323ad5c492d3c3b          fdp
# 4  bfba838c25cc634c  die_gruenen
